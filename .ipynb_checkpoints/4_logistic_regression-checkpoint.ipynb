# %% [markdown]
# # 3. Logistic Regression to Distingush Developing and Non-Developing TC seeds

# %% [markdown]
# ## Import statements

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (accuracy_score, precision_score, recall_score,
                             RocCurveDisplay, PrecisionRecallDisplay,
                             mean_squared_error, r2_score,
                             confusion_matrix, f1_score)
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ## Load and process data

# %%
# years = np.arange(2000,2019+1)
years_dev = np.arange(1980,2022+1)
years_nondev = [2000,2002,2003,2004,2005,2006,2007,2009,2010,2012,2014,2015,2016,2017,2018,2019,2020,2021]

dev_list = [f"./ERA5_extracted_years/developers_{year}_with_ERA5.nc" for year in years_dev]
nondev_list = [f"./ERA5_extracted_years/non-developer_12pointss_{year}_with_ERA5.nc" for year in years_nondev]

dev = xr.open_mfdataset(
    dev_list,
    combine="nested",
    concat_dim="track_point",
    join="outer"
)

nondev = xr.open_mfdataset(
    nondev_list,
    combine="nested",
    concat_dim="track_point",
    join="outer"
)

# define a function to process the data
def process_data(ds, label, num_track=12):

    # process to keep just x num of track points

    groups = ds.groupby("id").groups
    valid_ids = [cid for cid, idx in groups.items() if len(idx) >= num_track]

    keep_indices = []
    for id in valid_ids:
        idx = groups[id][:num_track]
        keep_indices.extend(idx)

    keep_indices = np.array(keep_indices, dtype=int)   # <-- FIX
    keep_indices = np.sort(keep_indices)

    ds_processed = ds.isel(track_point=keep_indices)

    keep_vars = ["vo_925", "conv_975", "q_700", "lat", "lon", "id", "time_dt"]
    ds_processed = ds_processed[keep_vars]

    # process to input and output

    groups = ds_processed.groupby("id")
    ids = list(groups.groups.keys())
    X_list = []
    y_list = []

    for id in ids:
        track = groups[id]

        arr = np.concatenate([
            track["vo_925"].values,
            track["conv_975"].values,
            track["q_700"].values,
            track["lat"].values,
            track["lon"].values,
        ])

        X_list.append(arr)
        y_list.append(label)

    return np.array(X_list), np.array(y_list)


X_dev, y_dev = process_data(dev, 1, num_track=12)
X_nondev, y_nondev = process_data(nondev, 0, num_track=12)

# %% [markdown]
# ## Split into testing and training sets

# %%
X = np.vstack([X_dev, X_nondev])
y = np.concatenate([y_dev, y_nondev])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %% [markdown]
# ## Train the model

# %%
model = LogisticRegression(max_iter=10000, class_weight='balanced')
model.fit(X_train, y_train)

y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)
# Out:
# /glade/u/home/smhenry/miniconda3/envs/analysis/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# ## Test the model

# %%
acc_train = accuracy_score(y_train, y_train_pred)
acc_test = accuracy_score(y_test, y_test_pred)

prec_train = precision_score(y_train, y_train_pred, zero_division=0)
prec_test = precision_score(y_test, y_test_pred, zero_division=0)

rec_train = recall_score(y_train, y_train_pred, zero_division=0)
rec_test = recall_score(y_test, y_test_pred, zero_division=0)

print("validation:")
print(f"Accuracy train: {acc_train}, Accuracy test: {acc_test}")
print(f"Precision train: {prec_train}, Precision test: {prec_test}")
print(f"Recall train: {rec_train}, Recall test: {rec_test}")
# Out:
# validation:
# Accuracy train: 0.7419753086419754, Accuracy test: 0.7432821497120922
# Precision train: 0.139186295503212, Precision test: 0.15849673202614378
# Recall train: 0.8024691358024691, Recall test: 0.8290598290598291

# %%
tn, fp, fn, tp = confusion_matrix(y_test, y_test_pred).ravel()

FAR = fp / (fp + tp) if (fp + tp) > 0 else 0
POFD = fp / (fp + tn) if (fp + tn) > 0 else 0
TNR = tn / (tn + fp) if (tn + fp) > 0 else 0
FPR = fp / (fp + tn) if (fp + tn) > 0 else 0
CSI = tp / (tp + fp + fn) if (tp + fp + fn) > 0 else 0
f1 = f1_score(y_test, y_test_pred, zero_division=0)

print(f"False Alarm Rate (FAR): {FAR}")
print(f"Probability of False Detection (POFD): {POFD}")
print(f"True Negative Rate (TNR): {TNR}")
print(f"False Positive Rate (FPR): {FPR}")
print(f"Critical Success Index (CSI): {CSI}")
print(f"F1 score: {f1}")
# Out:
# False Alarm Rate (FAR): 0.8415032679738562
# Probability of False Detection (POFD): 0.26182003050330455
# True Negative Rate (TNR): 0.7381799694966955
# False Positive Rate (FPR): 0.26182003050330455
# Critical Success Index (CSI): 0.15348101265822786
# F1 score: 0.2661179698216735

# %% [markdown]
# ## Visualize the results

# %%
y_prob_train = model.predict_proba(X_train)[:, 1]
y_prob_test = model.predict_proba(X_test)[:, 1]
print("ROC / PR curves:")
RocCurveDisplay.from_predictions(y_test, y_prob_test)
PrecisionRecallDisplay.from_predictions(y_test, y_prob_test)
# Out:
# ROC / PR curves:

# %% [markdown]
# ## Interpretation
#
# - No signs of overfitting: accuracy, precision, and recall are stable between training and testing.
# - Reasonable accuracy (.74), poor precision (0.16), and good recall (0.83)
# - High false alarm rate (0.84) indicates too many are identified as developing, high true negative rate indicates the model identifies non-developers well.

# %% [markdown]
# # What if the number of track points is increased?
#
# 12$\rightarrow$16
# (e.g. 54 to 72 hours)

# %%
# years = np.arange(2000,2019+1)
years_dev = np.arange(1980,2022+1)
years_nondev = [2001,2002,2003,2004,2005,2007,2009,2011,2012,2014,2015,2016,2017,2018,2019,2020]

dev_list = [f"./ERA5_extracted_years/developers_{year}_with_ERA5.nc" for year in years_dev]
nondev_list = [f"./ERA5_extracted_years/non-developer_16pointss_{year}_with_ERA5.nc" for year in years_nondev]

dev = xr.open_mfdataset(
    dev_list,
    combine="nested",
    concat_dim="track_point",
    join="outer"
)

nondev = xr.open_mfdataset(
    nondev_list,
    combine="nested",
    concat_dim="track_point",
    join="outer"
)

# define a function to process the data
def process_data(ds, label, num_track=12):

    # process to keep just x num of track points

    groups = ds.groupby("id").groups
    valid_ids = [cid for cid, idx in groups.items() if len(idx) >= num_track]

    keep_indices = []
    for id in valid_ids:
        idx = groups[id][:num_track]
        keep_indices.extend(idx)

    keep_indices = np.array(keep_indices, dtype=int)   # <-- FIX
    keep_indices = np.sort(keep_indices)

    ds_processed = ds.isel(track_point=keep_indices)

    keep_vars = ["vo_925", "conv_975", "q_700", "lat", "lon", "id", "time_dt"]
    ds_processed = ds_processed[keep_vars]

    # process to input and output

    groups = ds_processed.groupby("id")
    ids = list(groups.groups.keys())
    X_list = []
    y_list = []

    for id in ids:
        track = groups[id]

        arr = np.concatenate([
            track["vo_925"].values,
            track["conv_975"].values,
            track["q_700"].values,
            track["lat"].values,
            track["lon"].values,
        ])

        X_list.append(arr)
        y_list.append(label)

    return np.array(X_list), np.array(y_list)


X_dev, y_dev = process_data(dev, 1, num_track=16)
X_nondev, y_nondev = process_data(nondev, 0, num_track=16)

# %% [markdown]
# ## Split into testing and training sets

# %%
X = np.vstack([X_dev, X_nondev])
y = np.concatenate([y_dev, y_nondev])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %% [markdown]
# ## Train the model

# %%
model = LogisticRegression(max_iter=10000, class_weight='balanced')
model.fit(X_train, y_train)

y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)
# Out:
# /glade/u/home/smhenry/miniconda3/envs/analysis/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF F,G EVALUATIONS EXCEEDS LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# ## Test the model

# %%
acc_train = accuracy_score(y_train, y_train_pred)
acc_test = accuracy_score(y_test, y_test_pred)

prec_train = precision_score(y_train, y_train_pred, zero_division=0)
prec_test = precision_score(y_test, y_test_pred, zero_division=0)

rec_train = recall_score(y_train, y_train_pred, zero_division=0)
rec_test = recall_score(y_test, y_test_pred, zero_division=0)

print("validation:")
print(f"Accuracy train: {acc_train}, Accuracy test: {acc_test}")
print(f"Precision train: {prec_train}, Precision test: {prec_test}")
print(f"Recall train: {rec_train}, Recall test: {rec_test}")
# Out:
# validation:
# Accuracy train: 0.7503681885125184, Accuracy test: 0.7714776632302406
# Precision train: 0.20300751879699247, Precision test: 0.20711974110032363
# Recall train: 0.7941176470588235, Recall test: 0.7529411764705882

# %%
tn, fp, fn, tp = confusion_matrix(y_test, y_test_pred).ravel()

FAR = fp / (fp + tp) if (fp + tp) > 0 else 0
POFD = fp / (fp + tn) if (fp + tn) > 0 else 0
TNR = tn / (tn + fp) if (tn + fp) > 0 else 0
FPR = fp / (fp + tn) if (fp + tn) > 0 else 0
CSI = tp / (tp + fp + fn) if (tp + fp + fn) > 0 else 0
f1 = f1_score(y_test, y_test_pred, zero_division=0)

print(f"False Alarm Rate (FAR): {FAR}")
print(f"Probability of False Detection (POFD): {POFD}")
print(f"True Negative Rate (TNR): {TNR}")
print(f"False Positive Rate (FPR): {FPR}")
print(f"Critical Success Index (CSI): {CSI}")
print(f"F1 score: {f1}")
# Out:
# False Alarm Rate (FAR): 0.7928802588996764
# Probability of False Detection (POFD): 0.22706209453197404
# True Negative Rate (TNR): 0.772937905468026
# False Positive Rate (FPR): 0.22706209453197404
# Critical Success Index (CSI): 0.19393939393939394
# F1 score: 0.3248730964467005

# %% [markdown]
# ## Visualize the results

# %%
y_prob_train = model.predict_proba(X_train)[:, 1]
y_prob_test = model.predict_proba(X_test)[:, 1]
print("ROC / PR curves:")
RocCurveDisplay.from_predictions(y_test, y_prob_test)
PrecisionRecallDisplay.from_predictions(y_test, y_prob_test)
# Out:
# ROC / PR curves:

# %% [markdown]
# ## Interpret
#
# - Higher accuracy (0.79), precision (0.21) but lower recall (0.75) than previous model.
# - Smaller false alarm rate (0.79) and lower probability of false detection (0.23).
# - Metrics indicate the model improved by including an additional day of data.

# %% [markdown]
# # Next steps
#
# 1. Increase the temporal resolution of training data.
#     - Currently 6-hourly, but will linerarly interpolate the seed tracks to hourly.
# 2. Add more spatial information to the training data.
#     - The training data variables are for just one (lat, lon) point, so I will calculate the variables for the inner pouch region (1.5deg grid circle) and outer pouch region (5deg grid circle).
# 3. Improve the model.
#     - Once the training data are refined, the specific model design will be improved (e.g. scaling the data between developers and non-developers).
